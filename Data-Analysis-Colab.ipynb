# %% [markdown]
# <a href="https://colab.research.google.com/github/Dan-Brooks/Programming-for-Data-Analysis-Cmet/blob/main/Data-Analysis-Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Programming for Data Analysis** - CMP7005
# This Project will analysis 4 weather monitoring stations
